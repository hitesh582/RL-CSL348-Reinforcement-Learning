# %% [markdown]
# <a href="https://colab.research.google.com/github/hitesh582/RL-CSL348/blob/main/RL_Exp_2_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
x = np.random.randint(0,50,1000)
print(x)
# Out:
# [30 13 34 45 41 35 47 26  5 12 49 41  6  9 45  1  5 31 24 39 31 34 35 29
#  30 44 48 15 15 37 27 24 18 40 21 32 28 20 12 37 15 44 49  7 23  3 48  1
#   8  6 33  7 12  6 27 28 38 30 11 15 28 42 48 37  5 11 27 12 16  0 44 28
#  48 12 23 36  9 44 23 21  1 26  5 47 39  5 18 49 33 17 40 28 33 31 28 37
#  41 48 29 12 15 23  7  0  3 28 47 31  6 35 26 12 13 21 37 47 23 21 46  7
#   4 40 37 15 31 47 48 46 28 14  9 24 47 24 17 27 13  3 17  5  1 21 41 22
#  17 15 35  0 11 30 36 47 26 14 14 31  5 44 40 23 39 45 43 18 36 35 48 10
#   0 17  0 39  2 44  9 42 19 27  5 44 19  6 28 21 36 26 39 48 11 47 19 20
#  14 13 41 33 38 26  0  6 40 23 26 18 45 27 31  8 38  2 35 25 29  9 12 32
#  31 32 24 15 48 19 46 24 38 21 36 44 23 29  2  2 39  7 39 29 17  0 21 14
#  47 38 47 27 47 41 36 26 44 35 12 44  9 27 44 16 22 46 27 39 40 11 16 48
#  35 31 43  0 10  2 49 17 25 37 22 33 10 47 24 48 49  9 39 34 32 10 35 27
#  28 42 25  5  9 29 11 29 18 11 39 20 48 39 36  4  4 47 39 17 24 26  9 35
# ...

# %%
y = x + np.random.randint(0,10, 1000)
print(y)
# Out:
# [35 18 34 52 49 38 48 29  7 20 57 41 12  9 52  4  5 33 28 39 37 34 39 29
#  35 48 52 17 19 37 31 24 21 42 21 39 33 22 20 45 24 53 55  7 25 12 49 10
#   9  8 38 12 15 15 30 30 47 37 11 18 29 46 51 42  8 20 29 18 21  3 53 35
#  53 20 23 37 13 46 30 25  2 29 13 50 43  5 24 58 41 20 41 36 41 34 35 38
#  44 54 38 21 22 31 12  9  5 29 47 31 13 35 35 12 15 25 42 53 26 21 46 15
#   9 41 45 16 39 53 52 53 36 22 13 33 50 25 20 35 17  9 19 12  3 22 47 30
#  18 21 37  3 18 34 40 54 33 22 23 35  5 46 46 29 44 47 43 25 41 40 49 11
#   5 26  9 46  8 47 18 48 28 29 13 52 22 13 28 27 36 35 44 57 18 47 20 29
#  18 14 44 37 44 30  9  8 49 25 32 25 50 31 36 13 39  3 43 33 30 10 20 41
#  31 41 27 23 54 27 55 33 38 25 38 44 32 29  7 11 47 10 41 29 20  6 26 15
#  48 42 50 31 51 50 38 33 50 41 21 45 18 28 50 21 31 46 29 48 45 16 25 49
#  40 31 44  4 15  4 53 26 31 37 25 41 13 56 24 54 56 17 48 39 36 11 38 28
#  31 46 31 14 10 37 16 31 21 14 41 26 52 47 36 12  8 49 43 22 25 28 15 35
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.98079106],
#        [0.98079106, 1.        ]])

# %%
x = np.random.randint(0,50,1000)

# %%
z = 100 - x
np.corrcoef(x,z)
plt.scatter(x,z)
plt.show()

# %%
np.corrcoef(x,z)
# Out:
# array([[ 1., -1.],
#        [-1.,  1.]])

# %%
import pandas as pd

df = pd.DataFrame({'a': np.random.randint(0,50,1000)})
df['b'] = df['a'] + np.random.normal(0,50,1000)
df['c'] = 100 - df['a'] + np.random.normal(0,50,1000)
df['d'] = np.random.normal(0,50,1000)

df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.210477 -0.255716  0.006494
# b  0.210477  1.000000 -0.055790  0.086663
# c -0.255716 -0.055790  1.000000 -0.019440
# d  0.006494  0.086663 -0.019440  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize = (6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()
